# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.metrics import mean_squared_error, accuracy_score
from ucimlrepo import fetch_ucirepo

# %%
# Fetch dataset 
mushroom = fetch_ucirepo(id=73) 
  
# Save data as X and y variables
X = mushroom.data.features 
y = np.ravel(mushroom.data.targets)

# Expand dataframe columns and look at view dataframe
pd.set_option('display.max_columns', None)
X.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0         n          k           e          e                        s
# 1         b          k           e          c                        s
# 2         b          n           e          c                        s
# 3         n          n           e          e                        s
# 4         b          k           t          e                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# 1                        s                      w                      w
# 2                        s                      w                      w
# 3                        s                      w                      w
# 4                        s                      w                      w
#
#   veil-type veil-color ring-number ring-type spore-print-color population  \
# 0         p          w           o         p                 k          s
# 1         p          w           o         p                 n          n
# 2         p          w           o         p                 n          n
# 3         p          w           o         p                 k          s
# 4         p          w           o         e                 n          a
#
#   habitat
# 0       u
# 1       g
# 2       m
# 3       u
# 4       g

# %%
# Encoding data
# Factorizing all columns
for col in X.columns:
    X.loc[:,col] = pd.factorize(X[col], sort = True)[0]

# View first few rows of encoded data
X.iloc[0:5, 0:5]
# Out:
#   cap-shape cap-surface cap-color bruises odor
# 0         5           2         4       1    6
# 1         5           2         9       1    0
# 2         0           2         8       1    3
# 3         5           3         8       1    6
# 4         5           2         3       0    5

# %%
# Time to impute!
# Does our dataset have missing values?
X.isna().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# We are going to randomly assign observations in our dataset to be missing, and then see which impuattion methods perform best by comparing their results to our actual dataset. 
# Create copy of x variabesl
X_Na = X.copy()

# %%
# Assign 10% of new dataframe with NA values
for col in X_Na.columns:
    X_Na.loc[X_Na.sample(frac = 0.1).index, col] = np.nan

# %%
# Check to see missing values
X_Na.isna().sum()
# Out:
# cap-shape                   812
# cap-surface                 812
# cap-color                   812
# bruises                     812
# odor                        812
# gill-attachment             812
# gill-spacing                812
# gill-size                   812
# gill-color                  812
# stalk-shape                 812
# stalk-root                  812
# stalk-surface-above-ring    812
# stalk-surface-below-ring    812
# stalk-color-above-ring      812
# stalk-color-below-ring      812
# veil-type                   812
# veil-color                  812
# ring-number                 812
# ring-type                   812
# spore-print-color           812
# population                  812
# habitat                     812
# dtype: int64

# %%
X_Na
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            5           2         4       1    6             NaN
# 1            5           2         9       1  NaN               1
# 2            0           2         8       1    3               1
# 3          NaN           3         8       1    6               1
# 4            5           2         3       0    5               1
# ...        ...         ...       ...     ...  ...             ...
# 8119         3           2       NaN       0    5               0
# 8120         5           2         4       0    5               0
# 8121         2           2         4       0    5               0
# 8122         3           3       NaN     NaN    8               1
# 8123         5           2         4       0    5               0
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               0         1          4           0          2
# 1               0         0          4           0          1
# 2               0         0          5           0          1
# 3               0         1          5           0          2
# 4               1         0          4         NaN          2
# ...           ...       ...        ...         ...        ...
# 8119            0         0         11           0        NaN
# 8120            0         0         11           0         -1
# 8121            0         0          5           0         -1
# 8122          NaN         1        NaN           1         -1
# 8123            0         0         11           0         -1
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           2                        2                      7
# 1                           2                      NaN                      7
# 2                           2                        2                      7
# 3                           2                      NaN                      7
# 4                         NaN                        2                      7
# ...                       ...                      ...                    ...
# 8119                      NaN                        2                      5
# 8120                        2                        2                      5
# 8121                        2                      NaN                      5
# 8122                        2                        1                      7
# 8123                        2                        2                      5
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         7         0        NaN           1         4
# 1                         7         0          2           1         4
# 2                         7         0          2           1         4
# 3                         7         0          2           1         4
# 4                         7         0          2           1         0
# ...                     ...       ...        ...         ...       ...
# 8119                      5         0          1           1         4
# 8120                      5         0          0           1         4
# 8121                    NaN         0          1           1         4
# 8122                      7         0          2           1         0
# 8123                      5         0          1         NaN         4
#
#      spore-print-color population habitat
# 0                    2          3       5
# 1                    3          2       1
# 2                    3        NaN       3
# 3                    2        NaN       5
# 4                  NaN        NaN       1
# ...                ...        ...     ...
# 8119               NaN          1       2
# 8120                 0          4       2
# 8121                 0          1       2
# 8122                 7          4       2
# 8123                 4          1       2
#
# [8124 rows x 22 columns]

# %% [markdown]
# Imputation methoe #1: Filling NA values with the mode

# %%
# Impute with mode
X_mode_impute = X_Na.fillna(X_Na.mode().iloc[0])

# Check to make sure there are no NAs
X_mode_impute.isna().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# Impute with median (using SimpleImputer)
median_impute = SimpleImputer(strategy = 'median')
X_median_impute = median_impute.fit_transform(X_Na)
X_median_impute = pd.DataFrame(X_median_impute, columns = X.columns)
#Check fornas
X_median_impute.isna().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# Impute with KNN Imputer
knn_impute = KNNImputer(n_neighbors = 5)
X_knn_impute = knn_impute.fit_transform(X_Na)
x_knn_impute = pd.DataFrame(X_knn_impute, columns = X.columns)

# Check for na
x_knn_impute.isna().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# Calculate imputation accuracy using mean squared error
mse_mode = mean_squared_error(X, X_mode_impute)
mse_median = mean_squared_error(X, X_median_impute)
mse_knn = mean_squared_error(X, X_knn_impute)

# Report
print(f"Mode Imputation Performance: {mse_mode}")
print(f"Median Imputation Performance: {mse_median}")
print(f"KNN Imputation Performance: {mse_knn}")
# Out:
# Mode Imputation Performance: 0.4404737925786671
# Median Imputation Performance: 0.25284790295868587
# KNN Imputation Performance: 0.12266639810214404

# %%
# Random Forest Classifier with original data
# Split actual data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# Number of features to include for tuning
num_features = [1,4,7,10,13,16,19,22]
accuracy = []

for feature in num_features:
    rf_classifier = RandomForestClassifier(
    n_estimators = 50,
        max_depth = 3,
        random_state = 42,
        max_features = feature
    )
    
    rf_classifier.fit(X_train, y_train)
    
    # Predict and evaluate results
    
    y_pred = rf_classifier.predict(X_test)
    rf_accuracy = accuracy_score(y_test, y_pred)
    accuracy.append(rf_accuracy)
    
    print(f"Number of features:{feature}; Random Forest Accuracy: {rf_accuracy}")
# Out:
# Number of features:1; Random Forest Accuracy: 0.916735028712059
# Number of features:4; Random Forest Accuracy: 0.9848236259228876
# Number of features:7; Random Forest Accuracy: 0.9868744872846595
# Number of features:10; Random Forest Accuracy: 0.9835931091058244
# Number of features:13; Random Forest Accuracy: 0.9823625922887613
# Number of features:16; Random Forest Accuracy: 0.9860541427399507
# Number of features:19; Random Forest Accuracy: 0.9819524200164069
# Number of features:22; Random Forest Accuracy: 0.9577522559474979

# %%
# Split imputed data
X_train, X_test, y_train, y_test = train_test_split(X_knn_impute, y, test_size = 0.3, random_state = 42)

# %%
# Number of features to include for tuning
num_features = [1,4,7,10,13,16,19,22]
accuracy = []

for feature in num_features:
    rf_classifier = RandomForestClassifier(
    n_estimators = 50,
        max_depth = 3,
        random_state = 42,
        max_features = feature
    )
    
    rf_classifier.fit(X_train, y_train)
    
    # Predict and evaluate results
    
    y_pred = rf_classifier.predict(X_test)
    rf_accuracy = accuracy_score(y_test, y_pred)
    accuracy.append(rf_accuracy)
    
    print(f"Number of features:{feature}; Random Forest Accuracy: {rf_accuracy}")
# Out:
# Number of features:1; Random Forest Accuracy: 0.9171452009844134
# Number of features:4; Random Forest Accuracy: 0.9835931091058244
# Number of features:7; Random Forest Accuracy: 0.985233798195242
# Number of features:10; Random Forest Accuracy: 0.9864643150123051
# Number of features:13; Random Forest Accuracy: 0.9864643150123051
# Number of features:16; Random Forest Accuracy: 0.9716981132075472
# Number of features:19; Random Forest Accuracy: 0.9733388022969647
# Number of features:22; Random Forest Accuracy: 0.9569319114027892
